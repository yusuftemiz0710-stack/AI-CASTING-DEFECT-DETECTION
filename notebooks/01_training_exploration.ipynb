# %% [markdown]
# # 01 Training Exploration
#
# Eğitim metriklerini ve karşılaştırma tablosunu incelemek için küçük bir notebook.

# %%
import pandas as pd
pd.read_csv('outputs/tables/model_comparison.csv')
