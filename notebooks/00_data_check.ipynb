# %% [markdown]
# # 00 Data Check
#
# Bu notebook manifest ve EDA çıktılarının hızlı kontrolü için bırakılmıştır.

# %%
from src.utils import load_manifest
manifest = load_manifest()
manifest.groupby(['split', 'class_name']).size()
